# %%
import pandas as pd
import numpy as np

# %%
# Load the CSV file
df = pd.read_csv('AllNegative_0424_NewNames.csv')

# %%
# Assume the two columns are 'Column1' and 'Column2', and the certain value is 'value'
# Replace values less than 'value' with NaN
dfH = df.loc[:,'Cornell_Pos_S-01_LMT_PS_PMM_R0':'Cornell_Pos_S-50_LMH_LCT_PS_PMM_R1']
dfH[dfH < 10000] = np.nan

# %%
dfH.head()
# Out:
#    Cornell_Pos_S-01_LMT_PS_PMM_R0  Cornell_Pos_S-01_LMT_PS_PMM_R1  \
# 0                       1226234.0                        385427.0
# 1                        426166.0                        441196.0
# 2                       1095311.0                        147112.0
# 3                       1037785.0                        433319.0
# 4                        495960.0                        179603.0
#
#    Cornell_Pos_S-03_LCC_PS_R0  Cornell_Pos_S-03_LCC_PS_R1  \
# 0                   2849758.0                    537862.0
# 1                   1075231.0                    260201.0
# 2                   1519413.0                    183373.0
# 3                    542909.0                    494895.0
# 4                    104798.0                     70518.0
#
#    Cornell_Pos_S-04_LMT_PS_PMM_R0  Cornell_Pos_S-04_LMT_PS_PMM_R1  \
# 0                       5653096.0                        201624.0
# 1                       1257630.0                        324608.0
# ...

# %%
# Save the dataframe to a new CSV file
dfH.to_csv('10000Max_NonAvg+NaN_Neg.csv', index=False)
