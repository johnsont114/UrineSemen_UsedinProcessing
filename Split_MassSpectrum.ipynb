# %%
import pandas as pd
import csv

# %%
# Load Excel file
df = pd.read_excel('S6_Semen_NewComps.xlsx')

# %%
df.head()
# Out:
#    Alignment ID  Average Rt(min)  Average Mz  \
# 0          6206            9.380   351.21759
# 1          6209            4.936   351.21768
# 2          6211            7.725   351.21780
# 3          5630            9.330   333.20709
# 4          5632            4.936   333.20715
#
#                                      Metabolite name Adduct type  \
# 0  6,10a-dihydroxy-4-(hydroxymethyl)-4,7,11b-trim...      [M+H]+
# 1  6,10a-dihydroxy-4-(hydroxymethyl)-4,7,11b-trim...      [M+H]+
# 2  6,10a-dihydroxy-4-(hydroxymethyl)-4,7,11b-trim...      [M+H]+
# 3  5-[2-(furan-3-yl)ethyl]-8-hydroxy-5,6,8a-trime...      [M+H]+
# 4  5-[2-(furan-3-yl)ethyl]-8-hydroxy-5,6,8a-trime...      [M+H]+
#
#                                 Post curation result  Fill %  MS/MS assigned  \
# 0  ion correlated with 5630; adduct linked to 673...   0.222            True
# 1  ion correlated with 5632; ion correlated with ...   0.167            True
# ...

# %%
new_df = pd.DataFrame()

# %%
for i, row in enumerate(df['MS/MS spectrum']):
    temp_data = []
    for item in row.split():
        num1, num2 = item.split(':')
        temp_data.append([num1, num2])

    temp_df = pd.DataFrame(temp_data, columns=[f'Mass_{i+1}', f'Intensity_{i+1}'])

    if new_df.empty:
        new_df = temp_df
    else:
        new_df = pd.concat([new_df.reset_index(drop=True), temp_df.reset_index(drop=True)], axis=1)

# %%
new_df.to_csv('Mass+Intensity.csv', index=False)
